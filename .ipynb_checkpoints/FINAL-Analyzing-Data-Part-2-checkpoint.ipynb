# %%
# Importing libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# Reading in the panda dataframe
coffee_set = pd.read_csv("data/Coffee_Data")
coffee_set.head()
# Out:
#    Unnamed: 0 Country.of.Origin  Number.of.Bags Bag.Weight  Aroma  Flavor  \
# 0           0          Ethiopia             300      60 kg   8.67    8.83
# 1           1          Ethiopia             300      60 kg   8.75    8.67
# 2           2         Guatemala               5          1   8.42    8.50
# 3           3          Ethiopia             320      60 kg   8.17    8.58
# 4           4          Ethiopia             300      60 kg   8.25    8.50
#
#    Aftertaste  Acidity  Body  Balance  ...  Sweetness  Cupper.Points  \
# 0        8.67     8.75  8.50     8.42  ...       10.0           8.75
# 1        8.50     8.58  8.42     8.42  ...       10.0           8.58
# 2        8.42     8.42  8.33     8.42  ...       10.0           9.25
# 3        8.42     8.42  8.50     8.25  ...       10.0           8.67
# 4        8.25     8.50  8.42     8.33  ...       10.0           8.58
#
#    Total.Cup.Points  Moisture  Category.One.Defects  Quakers  \
# 0             90.58      0.12                     0      0.0
# 1             89.92      0.12                     0      0.0
# 2             89.75      0.00                     0      0.0
# 3             89.00      0.11                     0      0.0
# 4             88.83      0.12                     0      0.0
#
#    Category.Two.Defects  altitude_low_meters  altitude_high_meters  \
# 0                     0               1950.0                2200.0
# 1                     1               1950.0                2200.0
# 2                     0               1600.0                1800.0
# 3                     2               1800.0                2200.0
# 4                     2               1950.0                2200.0
#
#    altitude_mean_meters
# 0                2075.0
# 1                2075.0
# 2                1700.0
# 3                2000.0
# 4                2075.0
#
# [5 rows x 22 columns]

# %%
# Need to fixe index column so going to make Unamed the index
coffee_set.set_index("Unnamed: 0", inplace = True)

# %%
# Seeing if chnage took
coffee_set.head()
# Out:
#            Country.of.Origin  Number.of.Bags Bag.Weight  Aroma  Flavor  \
# Unnamed: 0
# 0                   Ethiopia             300      60 kg   8.67    8.83
# 1                   Ethiopia             300      60 kg   8.75    8.67
# 2                  Guatemala               5          1   8.42    8.50
# 3                   Ethiopia             320      60 kg   8.17    8.58
# 4                   Ethiopia             300      60 kg   8.25    8.50
#
#             Aftertaste  Acidity  Body  Balance  Uniformity  ...  Sweetness  \
# Unnamed: 0                                                  ...
# 0                 8.67     8.75  8.50     8.42        10.0  ...       10.0
# 1                 8.50     8.58  8.42     8.42        10.0  ...       10.0
# 2                 8.42     8.42  8.33     8.42        10.0  ...       10.0
# 3                 8.42     8.42  8.50     8.25        10.0  ...       10.0
# 4                 8.25     8.50  8.42     8.33        10.0  ...       10.0
#
#             Cupper.Points  Total.Cup.Points  Moisture  Category.One.Defects  \
# Unnamed: 0
# 0                    8.75             90.58      0.12                     0
# 1                    8.58             89.92      0.12                     0
# 2                    9.25             89.75      0.00                     0
# 3                    8.67             89.00      0.11                     0
# 4                    8.58             88.83      0.12                     0
#
#             Quakers  Category.Two.Defects  altitude_low_meters  \
# Unnamed: 0
# 0               0.0                     0               1950.0
# 1               0.0                     1               1950.0
# 2               0.0                     0               1600.0
# 3               0.0                     2               1800.0
# 4               0.0                     2               1950.0
#
#             altitude_high_meters  altitude_mean_meters
# Unnamed: 0
# 0                         2200.0                2075.0
# 1                         2200.0                2075.0
# 2                         1800.0                1700.0
# 3                         2200.0                2000.0
# 4                         2200.0                2075.0
#
# [5 rows x 21 columns]

# %%
# Change == "Worked"

# %%
# Converting the Country.of.Origin to binary
# Ethiopia is 1 and Guatemala is 0
coffee_set["Country.of.Origin"] = np.where(coffee_set["Country.of.Origin"] == "Ethiopia", 1, 0)

# %%
# Making sure the chnage took
coffee_set.head()
# Out:
#             Country.of.Origin  Number.of.Bags Bag.Weight  Aroma  Flavor  \
# Unnamed: 0
# 0                           1             300      60 kg   8.67    8.83
# 1                           1             300      60 kg   8.75    8.67
# 2                           0               5          1   8.42    8.50
# 3                           1             320      60 kg   8.17    8.58
# 4                           1             300      60 kg   8.25    8.50
#
#             Aftertaste  Acidity  Body  Balance  Uniformity  ...  Sweetness  \
# Unnamed: 0                                                  ...
# 0                 8.67     8.75  8.50     8.42        10.0  ...       10.0
# 1                 8.50     8.58  8.42     8.42        10.0  ...       10.0
# 2                 8.42     8.42  8.33     8.42        10.0  ...       10.0
# 3                 8.42     8.42  8.50     8.25        10.0  ...       10.0
# 4                 8.25     8.50  8.42     8.33        10.0  ...       10.0
#
#             Cupper.Points  Total.Cup.Points  Moisture  Category.One.Defects  \
# Unnamed: 0
# 0                    8.75             90.58      0.12                     0
# 1                    8.58             89.92      0.12                     0
# 2                    9.25             89.75      0.00                     0
# 3                    8.67             89.00      0.11                     0
# 4                    8.58             88.83      0.12                     0
#
#             Quakers  Category.Two.Defects  altitude_low_meters  \
# Unnamed: 0
# 0               0.0                     0               1950.0
# 1               0.0                     1               1950.0
# 2               0.0                     0               1600.0
# 3               0.0                     2               1800.0
# 4               0.0                     2               1950.0
#
#             altitude_high_meters  altitude_mean_meters
# Unnamed: 0
# 0                         2200.0                2075.0
# 1                         2200.0                2075.0
# 2                         1800.0                1700.0
# 3                         2200.0                2000.0
# 4                         2200.0                2075.0
#
# [5 rows x 21 columns]

# %%
# Change == "Worked"

# %%
# Need to see every column so I know what I want to use for splitting
coffee_set.columns
# Out:
# Index(['Country.of.Origin', 'Number.of.Bags', 'Bag.Weight', 'Aroma', 'Flavor',
#        'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity', 'Clean.Cup',
#        'Sweetness', 'Cupper.Points', 'Total.Cup.Points', 'Moisture',
#        'Category.One.Defects', 'Quakers', 'Category.Two.Defects',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %%
# Setting the columns I want to split for first graph
X = coffee_set[["Aroma", "Flavor", "Aftertaste", "Acidity", "Body", "Balance", "Uniformity"]]
y = coffee_set[["Number.of.Bags"]]

# %%
# dropping NA's/NanN if there is missing data before splitting
coffee_set.dropna(inplace = True)

# %%
# starting the train/test split on data by 80/20
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = 42, shuffle = False)

# Checking training shapes to see if it's the same
print(X_train.shape)
print(y_train.shape)
# Out:
# (4, 7)
# (4, 1)

# %%
# Checking testing shapes to see if it's the same
print(X_test.shape)
print(y_test.shape)
# Out:
# (1, 7)
# (1, 1)

# %%
# Instantiate a model object
LR = LinearRegression()

# %%
# Fitting the the model with the data.
# This is where the model learns from the data.
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Generating predictions
# This is where the X (input) goes into the model
# and math is done to estimate our y (output).
y_train_pred = LR.predict(X_train)
y_test_pred = LR.predict(X_test)

# %%
# Seeing how bad/good the prediction is
print(metrics.mean_squared_error(y_train, y_train_pred))
print(metrics.mean_squared_error(y_test, y_test_pred))
# Out:
# 1.1890721305449773e-24
# 5218.310631208299

# %%
# The MSE is way higher on the testing and I am not sure whether or not that is good or bad
# But I feel like I should watch out for it

# %%
# Calculate baseline_model.
baseline_model = y_train.mean()

# Calculate MSE for the baseline model.
baseline_pred = np.full(len(y_test), baseline_model)
mse_baseline = metrics.mean_squared_error(y_test, baseline_pred)

# Compare baseline MSE and testing MSE.
print(mse_baseline)
print(metrics.mean_squared_error(y_test, y_test_pred))
# Out:
# 4726.5625
# 5218.310631208299

# %%
# The baseline MSE is lower than the testing MSE.
# Since the gap is so huge, I think there is a chance of the graphs to be unaccurate

# %%
# Plotting our training predictions
# Visual to see what's happening and show class a representation
fig, ax = plt.subplots(figsize = (20, 10))

ax = plt.scatter(y_train, X_train.index, label = "trianing", color = "blue");
ax = plt.plot(y_train_pred, X_train.index, label = "training predictions", linewidth = 1, color = "orange");

# Graph lables (Title, X-axis, Y-axis)
plt.title("Bags of Coffee by Different Characteristics (Train)", size = 40);
plt.xlabel("Bags of Coffee", size = 20);
plt.xticks(rotation = 0, size = 20);
plt.ylabel("Coffee Characteristics", size = 20, rotation = 0, ha = "right");
plt.yticks(rotation = 0, size = 20);

plt.show()

# %%
# Plotting our testinng predictions
# Visual to see what's happening and show class a representation
fig2, ax = plt.subplots(figsize = (20, 10))

ax = plt.scatter(y_test, X_test.index, label = "testing", color = "blue");
ax = plt.plot(y_train_pred, X_train.index, label = "testing prediction", linewidth = 1, color = "orange");

# Graph lables (Title, X-axis, Y-axis)
plt.title("Bags of Coffee by Different Characteristics (Test)", size = 40);
plt.xlabel("Bags of Coffee", size = 20);
plt.xticks(rotation = 0, size = 20);
plt.ylabel("Coffee Characteristics", size = 20, rotation = 0, ha = "right");
plt.yticks(rotation = 0, size = 20);

plt.show()

# %%
# Saving visuals
fig.savefig("img/Coffee_And_Characteristics-Visuals-train.png", facecolor = "#FFFFFF")
fig2.savefig("img/Coffee_And_Characteristics-Visuals-test.png", facecolor = "#FFFFFF")

# %%
# Overall, I think the training graph shows how accurate w/ the points being exactly at the corners.
# I think I have something off in the code above honestly.
# For the testing set, I think it's pretty unaccurate.
# However, I always thought the line should be straight w/ no pointy edges.
